# %%
import os
import json

path = os.path.join("data", "programs.json")
with open(path, "r") as f:
    data = json.load(f)

list(data.keys())
# Out:
# ['Accounting (major)',
#  'Accounting (minor)',
#  'Actuarial Science (minor)',
#  'Advanced Engineering Ceramics (certificate)',
#  'Advertising (major)',
#  'Advertising | Persuasive Messaging (major)',
#  'Aerospace Engineering (major)',
#  'Aerospace Leadership (minor)',
#  'African American Studies (major)',
#  'African American Studies (minor)',
#  'African Languages (major)',
#  'African Studies (minor)',
#  'Agricultural Curriculum and Development (minor)',
#  'Agricultural Education and Communication (major)',
#  'Agricultural Operations Management (major)',
#  'Agricultural and Natural Resource Communication (minor)',
#  'Agricultural and Natural Resource Ethics and Policy (minor)',
#  'Agricultural and Natural Resource Law (minor)',
#  'Agroecology and Sustainable Food Systems (certificate)',
#  'American Indian and Indigenous Studies (minor)',
#  'Animal Genetics (certificate)',
#  'Animal Sciences (major)',
#  'Anthropology (major)',
#  'Anthropology (minor)',
# ...
